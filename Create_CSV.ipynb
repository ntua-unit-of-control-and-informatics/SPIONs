# %% [markdown]
# ### Import the Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Create Dataframe

# %%
cols = ['Name','Magnetic core','Surface','Overall size (nm)','Relaxivity (s-1/mmol Fe)( r2)','B0 (T)','Fe/cell (pg)','cell viability']

# %%
data=np.array([['Fe2O3-PLL',1,'PLL',15,None,1.5,64.51,0],
['uncoated',1,'uncoated',10,549,4.7,29.3,1],
['D-mannose-coated Fe2O3',1,'D-mannose',2,509,4.7,21.1,1],
['Fe2O3-PLL',1,'PLL',10,492,4.7,24.5,1],
['PDMAAm-coated-Fe2O3',1,'PDMMAm',10,89,4.7,23.2,1],
['N-dodecyl-PEI2k/SPIO',0,'N-dodecyl-grafted PEI 2K',54.7,345,3,7.1,0],
['iron oxide-loaded cationic nanovesicle',0,'PEI-SA',150,343.1,1.5,50.02,0],
['iron oxide-loaded cationic nanovesicle',0,'PEG-PGA',150,343.1,1.5,50.02,0],
['CMCS-SPIONs',0,'(Carboxymethyl)chitosan',55.4,160.5,1.5,26.7,0],
['ED-Pullulan coating SPIO',0,'Ethylenediamine Pullulan',94,None,7,65,0],
['IONP-6PEG-HA',0,'Amine-functionalizd six-armed PEG covalently linked to hyaluronic acid',75,454.5,3,1459,0],
['PDMAAm-coated-Fe2O3NPs',1,'PDMAAm',77.8,27.26,0.5,36.9,0],
['Citrate SPION',0,'Citrate',90.13, None,7,69.6,0],
['D-mannose coated SPIONs',1,'D-mannose',6,140.4,0.5,51.7,1],
['SPIO@SiO2-NH2',0,'SiO2-NH2',8.5,43.5,3,68.7,0],
['TAT-CLIO',0,'Tat peptide functionalized cross-linking dextran',65.2,73.4,0.47,2.15,0]])

# %%
df = pd.DataFrame(data=data,columns=cols, index=range(16))

# %%
df
# Out:
#                                       Name Magnetic core  \
# 0                                Fe2O3-PLL             1
# 1                                 uncoated             1
# 2                   D-mannose-coated Fe2O3             1
# 3                                Fe2O3-PLL             1
# 4                      PDMAAm-coated-Fe2O3             1
# 5                     N-dodecyl-PEI2k/SPIO             0
# 6   iron oxide-loaded cationic nanovesicle             0
# 7   iron oxide-loaded cationic nanovesicle             0
# 8                              CMCS-SPIONs             0
# 9                 ED-Pullulan coating SPIO             0
# 10                            IONP-6PEG-HA             0
# 11                  PDMAAm-coated-Fe2O3NPs             1
# 12                           Citrate SPION             0
# 13                 D-mannose coated SPIONs             1
# 14                           SPIO@SiO2-NH2             0
# 15                                TAT-CLIO             0
#
#                                               Surface Overall size (nm)  \
# 0                                                 PLL                15
# 1                                            uncoated                10
# 2                                           D-mannose                 2
# 3                                                 PLL                10
# 4                                              PDMMAm                10
# 5                            N-dodecyl-grafted PEI 2K              54.7
# 6                                              PEI-SA               150
# 7                                             PEG-PGA               150
# 8                             (Carboxymethyl)chitosan              55.4
# 9                            Ethylenediamine Pullulan                94
# 10  Amine-functionalizd six-armed PEG covalently l...                75
# 11                                             PDMAAm              77.8
# 12                                            Citrate             90.13
# 13                                          D-mannose                 6
# 14                                           SiO2-NH2               8.5
# 15   Tat peptide functionalized cross-linking dextran              65.2
#
#    Relaxivity (s-1/mmol Fe)( r2) B0 (T) Fe/cell (pg) cell viability
# 0                           None    1.5        64.51              0
# 1                            549    4.7         29.3              1
# 2                            509    4.7         21.1              1
# 3                            492    4.7         24.5              1
# 4                             89    4.7         23.2              1
# 5                            345      3          7.1              0
# 6                          343.1    1.5        50.02              0
# 7                          343.1    1.5        50.02              0
# 8                          160.5    1.5         26.7              0
# 9                           None      7           65              0
# 10                         454.5      3         1459              0
# 11                         27.26    0.5         36.9              0
# 12                          None      7         69.6              0
# 13                         140.4    0.5         51.7              1
# 14                          43.5      3         68.7              0
# 15                          73.4   0.47         2.15              0

# %% [markdown]
# ### Save the Dataset as a .csv

# %%
df.to_csv('mySet.csv',index=False)
